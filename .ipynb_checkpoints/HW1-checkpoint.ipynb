# %%
import pandas as pd

# %%
df = pd.read_csv("Baltimore911.csv", low_memory = False)
df.head()
# Out:
#     CrimeDate CrimeTime CrimeCode            Location          Description  \
# 0  02/08/2020   2:18:00        5D  1700 CLIFTVIEW AVE             BURGLARY
# 1  02/08/2020   6:00:00        6G   700 N STREEPER ST              LARCENY
# 2  02/08/2020   9:50:00       3JF     1400 N BROADWAY  ROBBERY - RESIDENCE
# 3  02/08/2020   9:50:00       3JF     1400 N BROADWAY  ROBBERY - RESIDENCE
# 4  02/08/2020  17:30:00        5A    1600 E OLIVER ST             BURGLARY
#
#   Inside/Outside   Weapon Post District     Neighborhood  Longitude  \
# 0              I      NaN  312  EASTERN      DARLEY PARK -76.593870
# 1              I      NaN  333  EASTERN  MADISON EASTEND -76.577425
# 2              I  FIREARM  314  EASTERN           OLIVER -76.594992
# 3              I  FIREARM  314  EASTERN           OLIVER -76.594992
# 4              I      NaN  314  EASTERN           OLIVER -76.595946
#
#     Latitude  Location 1             Premise  vri_name1  Total Incidents
# 0  39.315341         NaN  GROCERY/CONFECTION  Eastern 1                1
# 1  39.299094         NaN   ROW/TOWNHOUSE-OCC        NaN                1
# 2  39.306941         NaN   ROW/TOWNHOUSE-OCC        NaN                1
# 3  39.306941         NaN   ROW/TOWNHOUSE-OCC        NaN                1
# 4  39.307350         NaN   ROW/TOWNHOUSE-OCC  Eastern 1                1

# %%
pip install --upgrade pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (2.0.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (3.7.2)
# Requirement already satisfied: pydantic>=1.8.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.24.3)
# Requirement already satisfied: htmlmin>=0.1.12 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in /Users/ninesb7/anaconda3/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_profiling as pp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import pandas_profiling as pp
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/profile_report.py:15
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
# ---> 15 from pandas_profiling.model.alerts import AlertType
#      16 from pandas_profiling.model.describe import describe as describe_df
#      17 from pandas_profiling.model.sample import Sample
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/model/alerts.py:10
#       7 import pandas as pd
#       9 from pandas_profiling.config import Settings
# ---> 10 from pandas_profiling.model.correlations import perform_check_correlation
#      13 @unique
#      14 class AlertType(Enum):
#      15     """Alert types"""
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_profiling/model/correlations.py:8
#       6 import pandas as pd
#       7 from multimethod import multimethod
# ----> 8 from pandas.core.base import DataError
#      10 from pandas_profiling.config import Settings
#      13 class Correlation:
#
# ImportError: cannot import name 'DataError' from 'pandas.core.base' (/Users/ninesb7/anaconda3/lib/python3.11/site-packages/pandas/core/base.py)
